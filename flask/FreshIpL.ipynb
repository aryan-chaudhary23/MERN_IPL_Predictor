# %%
import numpy as np
import pandas as pd

# %%
delivery=pd.read_csv('deliveries.csv')
match=pd.read_csv('matches.csv')

# %%
delivery.sample(10)
# Out:
#         match_id  inning           batting_team           bowling_team  over  \
# 191558   1216543       2       Rajasthan Royals         Delhi Capitals     3
# 177334   1178428       2         Delhi Capitals       Rajasthan Royals     9
# 148819   1082643       2    Sunrisers Hyderabad          Gujarat Lions     0
# 39793     419158       1       Rajasthan Royals  Kolkata Knight Riders    15
# 72587     548366       1        Deccan Chargers        Kings XI Punjab    16
# 177885   1178431       1  Kolkata Knight Riders         Mumbai Indians     4
# 234127   1359508       1         Delhi Capitals    Sunrisers Hyderabad    17
# 107761    734041       1       Rajasthan Royals         Mumbai Indians    18
# 76492     597998       1       Delhi Daredevils  Kolkata Knight Riders    19
# 91754     598061       2  Kolkata Knight Riders          Pune Warriors    18
#
#         ball        batter      bowler  non_striker  batsman_runs  extra_runs  \
# ...

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
#we dont need all featues we will create our own dataset with features
#batting_team| bowling_team| city| runs_left| balls_left| wickets_left| total_runs_x| crr(curentrunrate)| rrr(requiredrunrate)| result
#now output is classification but we'll use algos that give us proabaility of a point like logisticRegs, SVM

# %%
total_score_df=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
total_score_df
#calculated har match ke har innings mein kitne runs banaye
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 1       335982       2          82
# 2       335983       1         240
# 3       335983       2         207
# 4       335984       1         129
# ...        ...     ...         ...
# 2212   1426310       2         174
# 2213   1426311       1         175
# 2214   1426311       2         139
# 2215   1426312       1         113
# 2216   1426312       2         114
#
# [2217 rows x 3 columns]

# %%
#now we will just pick up the first innings score 
#so that we can generate the dataset we want to make 
#ie. har team ne kitne runs banaye 
total_score_df=total_score_df[total_score_df['inning']==1]
total_score_df
#now we need to attach this total score with the match data frame usign match_id as common attribute
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
match_df=match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df.shape
# Out:
# (1095, 22)

# %%
match_df['team1'].unique()
#alot of these teams are now not playing so we need to remove them
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams=['Royal Challengers Bangalore','Kings XI Punjab','Delhi Capitals','Mumbai Indians','Kolkata Knight Riders','Rajasthan Royals','Chennai Super Kings','Sunrisers Hyderabad','Gujarat Titans','Lucknow Super Giants']

# %%
match_df['team1'] = match_df['team1'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team1'] = match_df['team1'].str.replace('Pune Warriors','Lucknow Super Giants')
match_df['team1'] = match_df['team1'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['team1'] = match_df['team1'].str.replace('Rising Pune Supergiant','Lucknow Super Giants')
match_df['team1'] = match_df['team1'].str.replace('Punjab Kings','Kings XI Punjab')
match_df['team2'] = match_df['team2'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Pune Warriors','Lucknow Super Giants')
match_df['team2'] = match_df['team2'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['team2'] = match_df['team2'].str.replace('Rising Pune Supergiant','Lucknow Super Giants')
match_df['team2'] = match_df['team2'].str.replace('Punjab Kings','Kings XI Punjab')

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Lucknow Super Giants', 'Gujarat Titans',
#        'Lucknow Super Giantss'], dtype=object)

# %%
#just changed the names of the old teams to new ones
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]
match_df.shape
# Out:
# (1067, 22)

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
match_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %%
match_df['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
match_df=match_df[match_df['method']!='D/L'] #ie. matches decided due to rain ignore them
match_df.shape
# Out:
# (1050, 22)

# %%
match_df=match_df[['match_id','city','winner','total_runs']]
match_df.head()
# Out:
#    match_id        city                       winner  total_runs
# 0    335982   Bangalore        Kolkata Knight Riders         222
# 1    335983  Chandigarh          Chennai Super Kings         240
# 2    335984       Delhi             Delhi Daredevils         129
# 3    335985      Mumbai  Royal Challengers Bangalore         165
# 4    335986     Kolkata        Kolkata Knight Riders         110

# %%
delivery_df=match_df.merge(delivery,on='match_id')
delivery_df.head()
#now we know at each ball who won the match, what is the target that needs to be achieved,in which city the match was occouring
# Out:
#    match_id       city                 winner  total_runs_x  inning  \
# 0    335982  Bangalore  Kolkata Knight Riders           222       1
# 1    335982  Bangalore  Kolkata Knight Riders           222       1
# 2    335982  Bangalore  Kolkata Knight Riders           222       1
# 3    335982  Bangalore  Kolkata Knight Riders           222       1
# 4    335982  Bangalore  Kolkata Knight Riders           222       1
#
#             batting_team                 bowling_team  over  ball  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4  Kolkata Knight Riders  Royal Challengers Bangalore     0     5
#
#         batter   bowler  non_striker  batsman_runs  extra_runs  total_runs_y  \
# 0   SC Ganguly  P Kumar  BB McCullum             0           1             1
# ...

# %%
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Delhi Daredevils','Delhi Capitals')
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Pune Warriors','Lucknow Super Giants')
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Gujarat Lions','Gujarat Titans')
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Rising Pune Supergiant','Lucknow Super Giants')
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Punjab Kings','Kings XI Punjab')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Delhi Daredevils','Delhi Capitals')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Pune Warriors','Lucknow Super Giants')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Gujarat Lions','Gujarat Titans')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Rising Pune Supergiant','Lucknow Super Giants')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Punjab Kings','Kings XI Punjab')

# %%
#just changed the names of the old teams to new ones
delivery_df=delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df=delivery_df[delivery_df['bowling_team'].isin(teams)]
match_df.shape
# Out:
# (1050, 4)

# %%
delivery_df=delivery_df[delivery_df['inning']==2]
delivery_df.head() #we just need to analyse the match when bowling
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
delivery_df.shape
#now to reach our targeted dataframe we need the following columns
#runsleft,ballsleft,wicketsleft,crr,rrr,result
backup=delivery_df

# %%
#there is a column total runs y telling kitne run pade that ball pe so we have to keep ading the previous
#runs and store it in a new column 
#now in the dataset this columns tell kitne run ban gaye abhi tk
#which can be directly used to create the column runsleft
delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']
delivery_df.tail()
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 251605   1426312  Chennai  Kolkata Knight Riders           113       2
# 251606   1426312  Chennai  Kolkata Knight Riders           113       2
# 251607   1426312  Chennai  Kolkata Knight Riders           113       2
# 251608   1426312  Chennai  Kolkata Knight Riders           113       2
# 251609   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball   batter  ...  \
# 251605  Kolkata Knight Riders  Sunrisers Hyderabad     9     5  SS Iyer  ...
# 251606  Kolkata Knight Riders  Sunrisers Hyderabad     9     6  VR Iyer  ...
# 251607  Kolkata Knight Riders  Sunrisers Hyderabad    10     1  VR Iyer  ...
# 251608  Kolkata Knight Riders  Sunrisers Hyderabad    10     2  SS Iyer  ...
# 251609  Kolkata Knight Riders  Sunrisers Hyderabad    10     3  VR Iyer  ...
#
#        batsman_runs extra_runs  total_runs_y  extras_type  is_wicket  \
# ...

# %%
delivery_df['balls_left']=120-(delivery_df['over']*6+delivery_df['ball'])
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
backup=delivery_df

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna("0")

# %%
delivery_df.loc[delivery_df['player_dismissed'] != '0', 'player_dismissed'] = '1'
print(delivery_df['player_dismissed'].unique())
# Out:
# ['0' '1']

# %%
backup=delivery_df

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].astype(int)

# %%
wickets=delivery_df.groupby('match_id')['player_dismissed'].cumsum().values
delivery_df['wickets']=10-wickets
delivery_df.tail()
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 251605   1426312  Chennai  Kolkata Knight Riders           113       2
# 251606   1426312  Chennai  Kolkata Knight Riders           113       2
# 251607   1426312  Chennai  Kolkata Knight Riders           113       2
# 251608   1426312  Chennai  Kolkata Knight Riders           113       2
# 251609   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball   batter  ...  \
# 251605  Kolkata Knight Riders  Sunrisers Hyderabad     9     5  SS Iyer  ...
# 251606  Kolkata Knight Riders  Sunrisers Hyderabad     9     6  VR Iyer  ...
# 251607  Kolkata Knight Riders  Sunrisers Hyderabad    10     1  VR Iyer  ...
# 251608  Kolkata Knight Riders  Sunrisers Hyderabad    10     2  SS Iyer  ...
# 251609  Kolkata Knight Riders  Sunrisers Hyderabad    10     3  VR Iyer  ...
#
# ...

# %%
#what we did was the dataset was telling us what player got out at a ball
#so using match id ie. in a match we calculated the players dismissed until each ball 
#and subtracted from 10 incidating these many wickets left
# now we just need to create two more columns to reach our desired dataframe
#ie. current runrate and required runrate and result(ie. who won)
# crr=runs/over(ie. abhi tak kitne over hogye)
# rrr=runs_left/overs_left

# %%
delivery_df.info()
backup=delivery_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 121703 entries, 124 to 251609
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          121703 non-null  int64
#  1   city              115691 non-null  object
#  2   winner            121676 non-null  object
#  3   total_runs_x      121703 non-null  int64
#  4   inning            121703 non-null  int64
#  5   batting_team      121703 non-null  object
#  6   bowling_team      121703 non-null  object
#  7   over              121703 non-null  int64
#  8   ball              121703 non-null  int64
#  9   batter            121703 non-null  object
#  10  bowler            121703 non-null  object
#  11  non_striker       121703 non-null  object
#  12  batsman_runs      121703 non-null  int64
#  13  extra_runs        121703 non-null  int64
#  14  total_runs_y      121703 non-null  int64
#  15  extras_type       6493 non-null    object
# ...

# %%
delivery_df['crr']=delivery_df['current_score']/(1+delivery_df['over'])
delivery_df['rrr']=delivery_df['runs_left']/(21-delivery_df['over'])
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
delivery_df.tail()
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 251605   1426312  Chennai  Kolkata Knight Riders           113       2
# 251606   1426312  Chennai  Kolkata Knight Riders           113       2
# 251607   1426312  Chennai  Kolkata Knight Riders           113       2
# 251608   1426312  Chennai  Kolkata Knight Riders           113       2
# 251609   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball   batter  ...  \
# 251605  Kolkata Knight Riders  Sunrisers Hyderabad     9     5  SS Iyer  ...
# 251606  Kolkata Knight Riders  Sunrisers Hyderabad     9     6  VR Iyer  ...
# 251607  Kolkata Knight Riders  Sunrisers Hyderabad    10     1  VR Iyer  ...
# 251608  Kolkata Knight Riders  Sunrisers Hyderabad    10     2  SS Iyer  ...
# 251609  Kolkata Knight Riders  Sunrisers Hyderabad    10     3  VR Iyer  ...
#
# ...

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)
delivery_df.sample(10)
# Out:
#         match_id          city                       winner  total_runs_x  \
# 133915   1082613       Kolkata                Gujarat Lions           187
# 219022   1359483       Kolkata        Kolkata Knight Riders           204
# 74357     598048     Bangalore  Royal Challengers Bangalore           161
# 225629   1359510     Bengaluru        Kolkata Knight Riders           200
# 92297     729295           NaN              Kings XI Punjab           193
# 235218   1422121       Kolkata        Kolkata Knight Riders           208
# 4501      336000        Jaipur             Rajasthan Royals           196
# 87644     598061        Ranchi                Pune Warriors           170
# 162636   1178403    Chandigarh  Royal Challengers Bangalore           173
# 23781     392229  Johannesburg              Kings XI Punjab           134
#
#         inning                 batting_team           bowling_team  over  \
# 133915       2               Gujarat Titans  Kolkata Knight Riders    17
# ...

# %%
final_df= delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]
final_df.head()
# Out:
#                     batting_team           bowling_team       city  runs_left  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        221
# 125  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        220
# 126  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        220
# 127  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        219
# 128  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        218
#
#      balls_left  wickets  total_runs_x  crr        rrr  result
# 124         119       10           222  1.0  10.523810       0
# 125         118       10           222  2.0  10.476190       0
# 126         117       10           222  2.0  10.476190       0
# 127         116       10           222  3.0  10.428571       0
# 128         115       10           222  4.0  10.380952       0

# %%
final_df.shape
backup=final_df

# %%
final_df[final_df.isna().any(axis=1)]
# Out:
#                        batting_team    bowling_team city  runs_left  \
# 90567   Royal Challengers Bangalore  Delhi Capitals  NaN        145
# 90568   Royal Challengers Bangalore  Delhi Capitals  NaN        145
# 90569   Royal Challengers Bangalore  Delhi Capitals  NaN        145
# 90570   Royal Challengers Bangalore  Delhi Capitals  NaN        144
# 90571   Royal Challengers Bangalore  Delhi Capitals  NaN        140
# ...                             ...             ...  ...        ...
# 184740               Mumbai Indians  Delhi Capitals  NaN          2
# 184741               Mumbai Indians  Delhi Capitals  NaN          1
# 184742               Mumbai Indians  Delhi Capitals  NaN          0
# 184743               Mumbai Indians  Delhi Capitals  NaN          0
# 184744               Mumbai Indians  Delhi Capitals  NaN         -1
#
#         balls_left  wickets  total_runs_x       crr       rrr  result
# 90567          119       10           145  0.000000  6.904762       1
# ...

# %%
final_df.isna().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# balls_left         0
# wickets            0
# total_runs_x       0
# crr                0
# rrr                0
# result             0
# dtype: int64

# %%
final_df['city'].value_counts()
# Out:
# city
# Mumbai            19895
# Kolkata           10127
# Chennai           10004
# Delhi              9821
# Hyderabad          8734
# Chandigarh         6814
# Bangalore          6623
# Jaipur             6324
# Pune               5449
# Abu Dhabi          4215
# Ahmedabad          3998
# Bengaluru          3396
# Durban             1725
# Lucknow            1545
# Dubai              1526
# Dharamsala         1523
# Visakhapatnam      1275
# Centurion          1269
# Sharjah            1110
# Navi Mumbai        1055
# Rajkot             1026
# Johannesburg        945
# Cuttack             839
# Ranchi              834
# Port Elizabeth      807
# Indore              717
# Raipur              689
# Cape Town           683
# Mohali              613
# Kanpur              429
# Nagpur              372
# Guwahati            367
# Kimberley           358
# East London         335
# Bloemfontein        249
# Name: count, dtype: int64

# %%
unique_cities = final_df['city'].dropna().unique()

# Define a function to fill NaN values with random unique city names
def fill_random_city(x):
    if pd.isna(x):
        return np.random.choice(unique_cities)  # Randomly select from unique cities
    return x

# Apply the function to the 'city' column to fill NaN values
final_df['city'] = final_df['city'].apply(fill_random_city)
final_df.isna().sum()
# Out:
# C:\Users\Aryan\AppData\Local\Temp\ipykernel_27892\3307316582.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['city'] = final_df['city'].apply(fill_random_city)
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
#shuffling all rows so we dont develope a bias by keeping all overs together
final_df=final_df.sample(final_df.shape[0])
final_df.head()
# Out:
#                        batting_team      bowling_team        city  runs_left  \
# 184401          Sunrisers Hyderabad    Delhi Capitals   Abu Dhabi        167
# 33755   Royal Challengers Bangalore   Kings XI Punjab  Chandigarh        115
# 116260        Kolkata Knight Riders  Rajasthan Royals      Mumbai        164
# 37123              Rajasthan Royals    Mumbai Indians      Jaipur        162
# 128155          Sunrisers Hyderabad    Gujarat Titans       Delhi         11
#
#         balls_left  wickets  total_runs_x       crr       rrr  result
# 184401         105        9           189  7.333333  8.789474       0
# 33755           70        8           181  7.333333  8.846154       1
# 116260          96        8           199  8.750000  9.111111       0
# 37123          100        7           174  3.000000  9.000000       0
# 128155           8        4           162  7.947368  3.666667       1

# %%
final_df.to_csv("req_df_IPL1.csv")

# %%
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  97362.000000  97362.000000  97362.000000  97362.000000  97362.000000
# mean      93.390317     62.579600      7.494731    168.024650      7.067282
# std       50.986376     33.456464      2.163507     30.622429      2.215851
# min       -6.000000     -3.000000      0.000000     62.000000      0.000000
# 25%       53.000000     34.000000      6.000000    148.000000      6.000000
# 50%       92.000000     63.000000      8.000000    168.000000      7.200000
# 75%      131.000000     91.750000      9.000000    187.000000      8.416667
# max      286.000000    119.000000     10.000000    287.000000     25.000000
#
#                 rrr
# count  97362.000000
# mean       7.842901
# std        3.459091
# min       -3.000000
# 25%        6.055556
# 50%        7.692308
# 75%        9.312500
# max       67.500000

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=pipe.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7915862125631651

# %%
import pickle
pickle.dump(pipe,open('IPLModel1.pkl','wb'))

# %%
#now we can use Random Forest here and its giving accuracy of 99% which is good
#but we need dont need accuracyt we needed probabilites of the respective teams of winning and loosing
#random forest also gives probabilities but they are very specific
#like 95%,5% 98%,2% 94%,6% ie. given such border cases only
